# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeClementAkazan/Deep-Learning/blob/main/TF2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %%
#Install tensorflow 2.0
# !pip install -q tensorflow==2.11.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 KB 21.7 MB/s eta 0:00:00

# %%
print(tf.__version__)
# Out:
# 2.9.2

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# 6. # Uploading your own data to Google Colab

# %% [markdown]
# # 1. Using Wget

# %%
#Download data from url
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
# Out:
# --2023-02-06 13:42:51--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10782 (11K) [application/x-httpd-php]
# Saving to: ‘wine.data’
#
# wine.data           100%[===================>]  10.53K  --.-KB/s    in 0s
#
# 2023-02-06 13:42:51 (74.1 MB/s) - ‘wine.data’ saved [10782/10782]

# %%
#Check whether the data is there 
# !ls
# Data does not have headers
# !head wine.data
# Out:
# 1OdyT_S3VjsA8foweFn_q417Azx5XfEBB  edit  index.html  sample_data  wine.data

# %%
#Check the data 
import pandas as pd
df=pd.read_csv("wine.data",header=None)

# %%
#Name the the first 4 columns
dt=df[[0,1,2,3,4]]
dt.columns=["Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium"]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,15]
dt.hist(); # Use semi column to suppress return value

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dt);

# %% [markdown]
# # 2. Using tf.keras to import data

# %%
url=   "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"

# %%
tf.keras.utils.get_file("wine.data",url)
# Out:
# ...
# 10782/10782 [==============================] - 0s 0us/step
# '/root/.keras/datasets/wine.data'

# %%
# Data does not have headers
# !head /root/.keras/datasets/wine.data

# %%
df=pd.read_csv("/root/.keras/datasets/wine.data",header=None)

# %% [markdown]
# # 3. Upload the file directly

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-89519ae0-dc86-424f-95a2-00d993924dcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89519ae0-dc86-424f-95a2-00d993924dcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
#  1OdyT_S3VjsA8foweFn_q417Azx5XfEBB   index.html   'wine (1).data'
#  edit				     sample_data   wine.data

# %%
df=pd.read_csv("wine (1).data",header=None)

# %% [markdown]
# Import python script in colab

# %%
srpt=files.upload()
# Out:
#      <input type="file" id="files-8bc92776-413e-4c3c-a149-1375dd640d86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bc92776-413e-4c3c-a149-1375dd640d86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from square_py import square
square()
# Out:
# 'Square'

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 4. Access files from Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Data_for Excel Training/'
# Out:
# Pfunda_temp.csv  Pfunda_temp.gsheet
